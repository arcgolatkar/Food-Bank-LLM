# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from geopy) (2.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
import time
import re
import os # For checking file existence

# --- Configuration ---
# Set defaults if city/state are often missing or known
DEFAULT_CITY = None # Example: "Washington" or None if usually present
DEFAULT_STATE = None # Example: "DC" or None
DEFAULT_COUNTRY = "USA"
DEFAULT_COUNTRY_CODE = "us" # 2-letter ISO code for country_codes

# --- Address Cleaning Function ---
def clean_and_format_address(address_str, city=None, state=None, country=None):
    """
    Cleans the address string and attempts to format it completely.
    Tries to remove leading names/non-address info.
    Removes common suite/unit patterns from the end.
    Appends default city/state/country if provided and seemingly missing.
    """
    if not isinstance(address_str, str) or not address_str.strip():
        return None # Handle empty or non-string data

    cleaned = address_str.strip()

    # --- Attempt to remove leading non-address info ---
    parts = cleaned.split()
    address_start_index = 0
    found_number = False
    for i, part in enumerate(parts):
        if part.isdigit() or (len(part) > 0 and part[0].isdigit()):
             # Basic check: consider this the start if it's a number
             address_start_index = i
             found_number = True
             break

    # If we found a likely street number and it's not the first word, strip leading parts
    if found_number and address_start_index > 0:
        cleaned = " ".join(parts[address_start_index:])
        # print(f"      -> Stripped leading info, starting address at: '{cleaned}'") # Debug
        
    elif not found_number:
        # Handle cases like "PO BOX 123" or intersections if needed later
        if "PO BOX" not in cleaned.upper() and " & " not in cleaned:
            # print(f"      -> Warning: No leading number found in address: {cleaned}") # Debug
            pass

    # --- Remove trailing suite/unit numbers ---
    cleaned = re.sub(r'[ ,]+\b(?:STE|SUITE|APT|UNIT|#)\s*[A-Z0-9-]+$', '', cleaned, flags=re.IGNORECASE).strip()
    cleaned = cleaned.rstrip(', ')

    # --- Add City/State/Country if missing (using defaults) ---
    full_address = cleaned
    has_state_zip_pattern = re.search(r',\s*([A-Z]{2}|\d{5}(-\d{4})?)\s*$', full_address, re.IGNORECASE)

    if city and state and not has_state_zip_pattern:
        # Avoid adding if city/state seems present as whole words
        in_str = False
        temp_lower = full_address.lower()
        if re.search(r'\b' + re.escape(city.lower()) + r'\b', temp_lower): in_str = True
        if not in_str and re.search(r'\b' + re.escape(state.lower()) + r'\b', temp_lower): in_str = True

        if not in_str:
            full_address = f"{cleaned}, {city}, {state}"
            # print(f"      -> Appended default city/state: '{full_address}'") # Debug

    # Append country if specified and not already present
    if country and country.upper() not in full_address.upper() and not re.search(r'\bUSA\b', full_address, re.IGNORECASE):
         if has_state_zip_pattern or (state and state.upper() in full_address.upper()):
              full_address = f"{full_address}, {country}"
              # print(f"      -> Appended default country: '{full_address}'") # Debug

    # Final cleanup
    full_address = re.sub(r', ,', ',', full_address)
    full_address = re.sub(r'\s+', ' ', full_address).strip()

    return full_address if full_address else None

# --- Geocoding Function ---
def geocode_address(geolocator, address_cleaned, attempt=1, max_attempts=3):
    """Geocode a *cleaned* address string with retry logic."""
    if not address_cleaned:
        return (None, None)
    try:
        # We assume 'address_cleaned' is already processed before calling this function
        location = geolocator.geocode(address_cleaned, timeout=10, country_codes=DEFAULT_COUNTRY_CODE)
        if location:
            return (location.latitude, location.longitude)
        else:
            print(f"  -> Geocoder returned None for: {address_cleaned}")
            return (None, None)
    except GeocoderTimedOut:
        if attempt <= max_attempts:
            print(f"Timeout geocoding '{address_cleaned}', retrying ({attempt}/{max_attempts})...")
            time.sleep(2**attempt)
            return geocode_address(geolocator, address_cleaned, attempt + 1) # Pass cleaned address in retry
        else:
            print(f"Failed to geocode '{address_cleaned}' after {max_attempts} attempts (Timeout).")
            return (None, None)
    except GeocoderServiceError as e:
        print(f"Geocoding service error for '{address_cleaned}': {e}")
        return (None, None)
    except Exception as e:
        print(f"An unexpected error occurred geocoding '{address_cleaned}': {e}")
        return (None, None)

# --- 1. Preprocessing Addresses ---
def preprocess_addresses(input_path, output_path):
    """Reads addresses, cleans them, geocodes, and saves to output."""
    try:
        # Try reading CSV first, then Excel
        if input_path.lower().endswith('.csv'):
            df = pd.read_csv(input_path)
            df.rename(columns = {'Shipping Address': 'Address'}, inplace=True)
        elif input_path.lower().endswith(('.xlsx', '.xls')):
             df = pd.read_csv(input_path)
        else:
             print(f"Error: Input file must be a CSV or Excel file (.csv, .xlsx, .xls). Path: {input_path}")
             return
    except FileNotFoundError:
        print(f"Error: Input file not found at {input_path}")
        return
    except Exception as e:
        print(f"Error reading input file: {e}")
        return

    # --- IMPORTANT: Define your address column name ---
    address_col = 'Address' # CHANGE THIS if your column name is different
    # Optional: Define city/state/zip columns if they exist
    city_col = None # e.g., 'City' or None
    state_col = None # e.g., 'State' or None
    # zip_col = None # e.g., 'ZipCode' or None
    # ---

    if address_col not in df.columns:
        print(f"Error: Input file must contain an '{address_col}' column.")
        return

    # Use a unique user_agent for Nominatim
    geolocator = Nominatim(user_agent="my_address_locator_app_v1") # CHANGE THIS to something unique

    latitudes = []
    longitudes = []
    processed_addresses = []

    print(f"Starting geocoding for {len(df)} addresses...")
    for index, row in df.iterrows():
        original_address = row[address_col]
        # Get city/state from columns if defined, otherwise use defaults
        current_city = row.get(city_col) if city_col and city_col in df.columns else DEFAULT_CITY
        current_state = row.get(state_col) if state_col and state_col in df.columns else DEFAULT_STATE

        print(f"\nProcessing {index + 1}/{len(df)}: {original_address}")

        # Clean and format the address
        address_to_geocode = clean_and_format_address(
            original_address, current_city, current_state, DEFAULT_COUNTRY
        )
        processed_addresses.append(address_to_geocode)

        if address_to_geocode:
            print(f"  -> Attempting to geocode: {address_to_geocode}")
            lat, lon = geocode_address(geolocator, address_to_geocode)
        else:
            print(f"  -> Skipping due to empty/invalid address after cleaning.")
            lat, lon = None, None

        latitudes.append(lat)
        longitudes.append(lon)

        time.sleep(1.1) # Respect Nominatim rate limit (1 req/sec)

    # Add new columns to the DataFrame
    # Keep original address for display, processed for debugging
    df['Original_Address'] = df[address_col]
    df['Processed_For_Geocoding'] = processed_addresses
    df['Latitude'] = latitudes
    df['Longitude'] = longitudes

    # Save results to CSV (recommended over Excel for simplicity)
    df.to_csv(output_path, index=False)
    print(f"\nGeocoding complete. Results saved to {output_path}")

    failures = df['Latitude'].isna().sum()
    print(f"Total addresses: {len(df)}, Successful: {len(df) - failures}, Failed: {failures}")

# --- 2. Find Closest Addresses ---
def find_closest(user_address_str, geocoded_data_path, num_closest=10):
    """
    Finds the N closest *distinct* addresses from the pre-geocoded file.
    Uniqueness is based on the 'Processed_For_Geocoding' column.
    """
    try:
        df_geocoded = pd.read_csv(geocoded_data_path)
        df_geocoded['Latitude'] = pd.to_numeric(df_geocoded['Latitude'], errors='coerce')
        df_geocoded['Longitude'] = pd.to_numeric(df_geocoded['Longitude'], errors='coerce')
        df_geocoded.dropna(subset=['Latitude', 'Longitude'], inplace=True)

        if df_geocoded.empty:
            print("Error: No valid geocoded addresses found in the data file.")
            return []
    except FileNotFoundError:
        print(f"Error: Geocoded data file not found at {geocoded_data_path}")
        print("Tip: Run the preprocessing step first.")
        return []
    except Exception as e:
        print(f"Error loading or processing geocoded data: {e}")
        return []

    # Geocode the user's input address
    # Ensure you have a unique user_agent string
    geolocator = Nominatim(user_agent="my_address_locator_app_v1_runtime_distinct") 
    print(f"\nGeocoding user address: {user_address_str}")

    # Assuming clean_and_format_address is defined elsewhere
    user_address_cleaned = clean_and_format_address( 
        user_address_str, DEFAULT_CITY, DEFAULT_STATE, DEFAULT_COUNTRY
    )
    if not user_address_cleaned:
         print(f"Could not clean the user address: {user_address_str}")
         return []

    print(f"  -> Cleaned user address: {user_address_cleaned}")
    # Assuming geocode_address is defined elsewhere
    user_lat, user_lon = geocode_address(geolocator, user_address_cleaned) 

    if user_lat is None or user_lon is None:
        print(f"Could not geocode the user address: '{user_address_cleaned}'")
        return []

    user_coords = (user_lat, user_lon)
    print(f"User coordinates: {user_coords}")

    # --- Calculate all distances ---
    all_distances = []
    # Determine which column to use for uniqueness check and display
    # Using 'Processed_For_Geocoding' ensures we treat identical cleaned addresses as duplicates
    # If you want uniqueness based on 'Original_Address', change this.
    unique_check_col = 'Processed_For_Geocoding' 
    
    # Fallback if the preferred column doesn't exist
    if unique_check_col not in df_geocoded.columns:
        if 'Original_Address' in df_geocoded.columns:
            unique_check_col = 'Original_Address'
            print(f"Warning: '{unique_check_col}' column not found. Using 'Original_Address' for uniqueness.")
        else:
             # As a last resort, maybe use the first column if 'Address' isn't there? Unlikely needed.
             print(f"Error: Column '{unique_check_col}' not found for uniqueness check.")
             return []

    for index, row in df_geocoded.iterrows():
        # Skip rows where the address used for uniqueness check is missing/NaN
        if pd.isna(row[unique_check_col]):
            continue
            
        list_coords = (row['Latitude'], row['Longitude'])
        address_for_uniqueness = row[unique_check_col]
        
        # Use Original_Address for display if available, otherwise use the uniqueness check column
        display_addr_col = unique_check_col
        display_addr = row[display_addr_col] if not pd.isna(row[display_addr_col]) else address_for_uniqueness

        try:
            distance_km = geodesic(user_coords, list_coords).km
            # Store distance, the address used for uniqueness check, and the address to display
            all_distances.append((distance_km, address_for_uniqueness, display_addr))
        except ValueError as e:
            print(f"Warn: Could not calculate distance for coords {list_coords} / address '{address_for_uniqueness}': {e}")
            continue

    # --- Sort by distance ---
    all_distances.sort(key=lambda x: x[0])

    # --- Filter for unique addresses ---
    unique_results = []
    seen_addresses = set() # Keep track of addresses we've already added

    for dist, unique_addr, display_addr in all_distances:
        # Convert to string just in case there are non-string types, though unlikely after cleaning
        unique_addr_str = str(unique_addr) 
        if unique_addr_str not in seen_addresses:
            unique_results.append((dist, display_addr)) # Add the display address to results
            seen_addresses.add(unique_addr_str)         # Mark this unique address as seen
            if len(unique_results) >= num_closest:      # Stop if we have enough unique results
                break

    return unique_results

# %%
# --- Configuration: File Paths ---
INPUT_FILE = 'CAFB_Shopping_Partners_Data.csv'  # CHANGE THIS to your input Excel or CSV file name
GECODED_FILE = 'geocoded_addresses.csv' # Output file name

preprocess_addresses(INPUT_FILE, GECODED_FILE)
# Out:
# Starting geocoding for 924 addresses...
#
# Processing 1/924: gloria ward-ravenell 2263 mount view place, se washington DC 20020
#   -> Attempting to geocode: 2263 mount view place, se washington DC 20020
#   -> Geocoder returned None for: 2263 mount view place, se washington DC 20020
#
# Processing 2/924: Attn: St. Martin's Social Service 1908 North Capitol Street NW Washington DC 20002
#   -> Attempting to geocode: 1908 North Capitol Street NW Washington DC 20002
#
# Processing 3/924: Attn: Bethesda Cares 5033 Wilson Lane Bethesda MD 20814
#   -> Attempting to geocode: 5033 Wilson Lane Bethesda MD 20814
#
# Processing 4/924: Attn: Bethesda Cares 5033 Wilson Lane Bethesda MD 20814
#   -> Attempting to geocode: 5033 Wilson Lane Bethesda MD 20814
#
# Processing 5/924: Attn: Bethesda Cares 5033 Wilson Lane Bethesda MD 20814
#   -> Attempting to geocode: 5033 Wilson Lane Bethesda MD 20814
#
# Processing 6/924: Attn: Bethesda Cares 5033 Wilson Lane Bethesda MD 20814
#   -> Attempting to geocode: 5033 Wilson Lane Bethesda MD 20814
#
# Processing 7/924: Attn: Bethesda Cares 5033 Wilson Lane Bethesda MD 20814
#   -> Attempting to geocode: 5033 Wilson Lane Bethesda MD 20814
#
# Processing 8/924: Attn: Brookland Senior Day Care Center, Inc. 6210 Chillum Place NW Washington DC 20011
#   -> Attempting to geocode: 6210 Chillum Place NW Washington DC 20011
#
# Processing 9/924: Attn: City of David Ministries 2900 Boones Lane District Heights MD 20747
#   -> Attempting to geocode: 2900 Boones Lane District Heights MD 20747
#   -> Geocoder returned None for: 2900 Boones Lane District Heights MD 20747
#
# Processing 10/924: Attn: City of David Ministries 2900 Boones Lane District Heights MD 20747
#   -> Attempting to geocode: 2900 Boones Lane District Heights MD 20747
#   -> Geocoder returned None for: 2900 Boones Lane District Heights MD 20747
#
# Processing 11/924: Attn: City of Greenbelt Food Pantry 25 Crescent Rd Greenbelt MD 20770
#   -> Attempting to geocode: 25 Crescent Rd Greenbelt MD 20770
#
# Processing 12/924: Attn: Fountain Community Enrichment Inc. 15853 Commerce Court Upper Marlboro MD 20774
#   -> Attempting to geocode: 15853 Commerce Court Upper Marlboro MD 20774
#   -> Geocoder returned None for: 15853 Commerce Court Upper Marlboro MD 20774
#
# Processing 13/924: Attn: Hope Presbyterian Church 1100 Enterprise Road Mitchellville MD 20721
#   -> Attempting to geocode: 1100 Enterprise Road Mitchellville MD 20721
#   -> Geocoder returned None for: 1100 Enterprise Road Mitchellville MD 20721
#
# Processing 14/924: Attn: Kingdom Care Center 11700 Beltsville Drive Beltsville MD 20705
#   -> Attempting to geocode: 11700 Beltsville Drive Beltsville MD 20705
#
# Processing 15/924: Attn: Mission of Love Charities, Inc. 6180 Central Avenue Capitol Heights MD 20743
#   -> Attempting to geocode: 6180 Central Avenue Capitol Heights MD 20743
#   -> Geocoder returned None for: 6180 Central Avenue Capitol Heights MD 20743
#
# Processing 16/924: Attn: Mission of Love Charities, Inc. 6180 Central Avenue Capitol Heights MD 20743
#   -> Attempting to geocode: 6180 Central Avenue Capitol Heights MD 20743
#   -> Geocoder returned None for: 6180 Central Avenue Capitol Heights MD 20743
#
# Processing 17/924: Attn: Mission of Love Charities, Inc. 6180 Central Avenue Capitol Heights MD 20743
#   -> Attempting to geocode: 6180 Central Avenue Capitol Heights MD 20743
#   -> Geocoder returned None for: 6180 Central Avenue Capitol Heights MD 20743
#
# Processing 18/924: Attn: Mission of Love Charities, Inc. 6180 Central Avenue Capitol Heights MD 20743
#   -> Attempting to geocode: 6180 Central Avenue Capitol Heights MD 20743
#   -> Geocoder returned None for: 6180 Central Avenue Capitol Heights MD 20743
#
# Processing 19/924: Attn: Mission of Love Charities, Inc. 6180 Central Avenue Capitol Heights MD 20743
#   -> Attempting to geocode: 6180 Central Avenue Capitol Heights MD 20743
#   -> Geocoder returned None for: 6180 Central Avenue Capitol Heights MD 20743
#
# Processing 20/924: Attn: Montgomery County Family Center 12247 Georgia Ave. Silver Spring MD 20902
#   -> Attempting to geocode: 12247 Georgia Ave. Silver Spring MD 20902
#
# Processing 21/924: Attn: SOME 71 O ST NW Washington DC 20002
#   -> Attempting to geocode: 71 O ST NW Washington DC 20002
#
# Processing 22/924: Attn: The ARK of DC Foundation 1818 New York Ave. NE Washington DC 20002
#   -> Attempting to geocode: 1818 New York Ave. NE Washington DC 20002
#
# Processing 23/924: Attn: Catholic University of America: The Cardinal Cupboard 620 Michigan Ave NE Washington DC 20064
#   -> Attempting to geocode: 620 Michigan Ave NE Washington DC 20064
#
# Processing 24/924: Attn: Catholic University of America: The Cardinal Cupboard 620 Michigan Ave NE Washington DC 20064
#   -> Attempting to geocode: 620 Michigan Ave NE Washington DC 20064
#
# Processing 25/924: Attn: Catholic University of America: The Cardinal Cupboard 620 Michigan Ave NE Washington DC 20064
#   -> Attempting to geocode: 620 Michigan Ave NE Washington DC 20064
#
# Processing 26/924: Attn: Catholic University of America: The Cardinal Cupboard 620 Michigan Ave NE Washington DC 20064
#   -> Attempting to geocode: 620 Michigan Ave NE Washington DC 20064
#
# Processing 27/924: Attn: Faith Tabernacle of Prayer 2465 Alabama Ave SE Washington DC 20020
#   -> Attempting to geocode: 2465 Alabama Ave SE Washington DC 20020
#
# Processing 28/924: Attn: Code 3 Association 2929 Graham Road Falls Church VA 22042
#   -> Attempting to geocode: 3 Association 2929 Graham Road Falls Church VA 22042
#   -> Geocoder returned None for: 3 Association 2929 Graham Road Falls Church VA 22042
#
# Processing 29/924: Attn: ECD - Edgewood Commons 8403 Colesville Rd Suite 1150 Silver Spring MD 20910
#   -> Attempting to geocode: 8403 Colesville Rd Suite 1150 Silver Spring MD 20910
#   -> Geocoder returned None for: 8403 Colesville Rd Suite 1150 Silver Spring MD 20910
#
# Processing 30/924: Attn: Catholic University of America: The Cardinal Cupboard 620 Michigan Ave NE Washington DC 20064
#   -> Attempting to geocode: 620 Michigan Ave NE Washington DC 20064
#
# Processing 31/924: Mount Jezreel Baptist Church 317 N Payne Street Alexandria VA 22314
#   -> Attempting to geocode: 317 N Payne Street Alexandria VA 22314
#
# Processing 32/924: Attn: Lorton Community Action Center 9520 Richmond Hwy door A3 Lorton VA 22079
#   -> Attempting to geocode: 9520 Richmond Hwy door A3 Lorton VA 22079
#   -> Geocoder returned None for: 9520 Richmond Hwy door A3 Lorton VA 22079
#
# Processing 33/924: Attn: Lorton Community Action Center 9520 Richmond Hwy door A3 Lorton VA 22079
#   -> Attempting to geocode: 9520 Richmond Hwy door A3 Lorton VA 22079
#   -> Geocoder returned None for: 9520 Richmond Hwy door A3 Lorton VA 22079
#
# Processing 34/924: Attn: Lorton Community Action Center 9520 Richmond Hwy door A3 Lorton VA 22079
#   -> Attempting to geocode: 9520 Richmond Hwy door A3 Lorton VA 22079
#   -> Geocoder returned None for: 9520 Richmond Hwy door A3 Lorton VA 22079
#
# Processing 35/924: Attn: District House GWU 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Attempting to geocode: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Geocoder returned None for: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#
# Processing 36/924: Attn: District House GWU 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Attempting to geocode: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Geocoder returned None for: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#
# Processing 37/924: Attn: District House GWU 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Attempting to geocode: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Geocoder returned None for: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#
# Processing 38/924: Attn: District House GWU 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Attempting to geocode: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Geocoder returned None for: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#
# Processing 39/924: Attn: District House GWU 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Attempting to geocode: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#   -> Geocoder returned None for: 800 21st Street NW Ground Floor, Military and Veteran Services Washington DC 20052
#
# Processing 40/924: Attn: Oxon Hill Food Pantry 4915 Saint Barnabas Road Temple Hills MD 20748
#   -> Attempting to geocode: 4915 Saint Barnabas Road Temple Hills MD 20748
#
# Processing 41/924: Attn: The Father McKenna Center 900 North Capital St NW Washington DC DC 20002
#   -> Attempting to geocode: 900 North Capital St NW Washington DC DC 20002
#   -> Geocoder returned None for: 900 North Capital St NW Washington DC DC 20002
#
# Processing 42/924: Attn: The Father McKenna Center 900 North Capital St NW Washington DC DC 20002
#   -> Attempting to geocode: 900 North Capital St NW Washington DC DC 20002
#   -> Geocoder returned None for: 900 North Capital St NW Washington DC DC 20002
#
# Processing 43/924: Attn: The Father McKenna Center 900 North Capital St NW Washington DC DC 20002
#   -> Attempting to geocode: 900 North Capital St NW Washington DC DC 20002
#   -> Geocoder returned None for: 900 North Capital St NW Washington DC DC 20002
#
# Processing 44/924: Attn: The Father McKenna Center 900 North Capital St NW Washington DC DC 20002
#   -> Attempting to geocode: 900 North Capital St NW Washington DC DC 20002
#   -> Geocoder returned None for: 900 North Capital St NW Washington DC DC 20002
#
# Processing 45/924: Brighter Day Ministries Food Pantry 3209 5th Street SE Washington DC 20032
#   -> Attempting to geocode: 3209 5th Street SE Washington DC 20032
#
# Processing 46/924: Attn: Foggy Bottom Food Pantry 1920 G Street NW Washington DC 20006
#   -> Attempting to geocode: 1920 G Street NW Washington DC 20006
#
# Processing 47/924: Attn: Food For Others 2938 Prosperity Avenue Fairfax VA 22031
#   -> Attempting to geocode: 2938 Prosperity Avenue Fairfax VA 22031
#
# Processing 48/924: Attn: Food For Others 2938 Prosperity Avenue Fairfax VA 22031
#   -> Attempting to geocode: 2938 Prosperity Avenue Fairfax VA 22031
#
# Processing 49/924: Attn: Food For Others 2938 Prosperity Avenue Fairfax VA 22031
#   -> Attempting to geocode: 2938 Prosperity Avenue Fairfax VA 22031
#
# Processing 50/924: Attn: Food For Others 2938 Prosperity Avenue Fairfax VA 22031
#   -> Attempting to geocode: 2938 Prosperity Avenue Fairfax VA 22031
#
# Processing 51/924: Attn: Cornerstones, Inc. 11484 Washington Plz W  #120 Reston VA 20190
#   -> Attempting to geocode: 11484 Washington Plz W #120 Reston VA 20190
#   -> Geocoder returned None for: 11484 Washington Plz W #120 Reston VA 20190
#
# Processing 52/924: Attn: Cornerstones, Inc. 11484 Washington Plz W  #120 Reston VA 20190
#   -> Attempting to geocode: 11484 Washington Plz W #120 Reston VA 20190
#   -> Geocoder returned None for: 11484 Washington Plz W #120 Reston VA 20190
#
# Processing 53/924: Attn: Cornerstones, Inc. 11484 Washington Plz W  #120 Reston VA 20190
#   -> Attempting to geocode: 11484 Washington Plz W #120 Reston VA 20190
#   -> Geocoder returned None for: 11484 Washington Plz W #120 Reston VA 20190
#
# Processing 54/924: Attn: Cornerstones, Inc. 11484 Washington Plz W  #120 Reston VA 20190
#   -> Attempting to geocode: 11484 Washington Plz W #120 Reston VA 20190
#   -> Geocoder returned None for: 11484 Washington Plz W #120 Reston VA 20190
#
# Processing 55/924: Attn: Cornerstones, Inc. 11484 Washington Plz W  #120 Reston VA 20190
#   -> Attempting to geocode: 11484 Washington Plz W #120 Reston VA 20190
#   -> Geocoder returned None for: 11484 Washington Plz W #120 Reston VA 20190
#
# Processing 56/924: Attn: Cornerstones, Inc. 11484 Washington Plz W  #120 Reston VA 20190
#   -> Attempting to geocode: 11484 Washington Plz W #120 Reston VA 20190
#   -> Geocoder returned None for: 11484 Washington Plz W #120 Reston VA 20190
#
# Processing 57/924: Mary House 4303 13th st NE Washington DC 20017
#   -> Attempting to geocode: 4303 13th st NE Washington DC 20017
#
# Processing 58/924: Attn: Columbia Baptist Church 3245 Glen Carlyn Rd. Falls Church VA 22041
#   -> Attempting to geocode: 3245 Glen Carlyn Rd. Falls Church VA 22041
#   -> Geocoder returned None for: 3245 Glen Carlyn Rd. Falls Church VA 22041
#
# Processing 59/924: Attn: Salvation Army- Sherman 3335 Sherman Ave. NW Washington DC 20010
#   -> Attempting to geocode: 3335 Sherman Ave. NW Washington DC 20010
#
# Processing 60/924: Attn: United Community Ministry 7511 Fordson Road Alexandria VA 22306
#   -> Attempting to geocode: 7511 Fordson Road Alexandria VA 22306
#   -> Geocoder returned None for: 7511 Fordson Road Alexandria VA 22306
#
# Processing 61/924: Attn: United Community Ministry 7511 Fordson Road Alexandria VA 22306
#   -> Attempting to geocode: 7511 Fordson Road Alexandria VA 22306
#   -> Geocoder returned None for: 7511 Fordson Road Alexandria VA 22306
#
# Processing 62/924: Attn: United Community Ministry 7511 Fordson Road Alexandria VA 22306
#   -> Attempting to geocode: 7511 Fordson Road Alexandria VA 22306
#   -> Geocoder returned None for: 7511 Fordson Road Alexandria VA 22306
#
# Processing 63/924: Attn: United Community Ministry 7511 Fordson Road Alexandria VA 22306
#   -> Attempting to geocode: 7511 Fordson Road Alexandria VA 22306
#   -> Geocoder returned None for: 7511 Fordson Road Alexandria VA 22306
#
# Processing 64/924: Attn: United Community Ministry 7511 Fordson Road Alexandria VA 22306
#   -> Attempting to geocode: 7511 Fordson Road Alexandria VA 22306
#   -> Geocoder returned None for: 7511 Fordson Road Alexandria VA 22306
#
# Processing 65/924: Attn: Mount Moriah Baptist Church 1636 East Capital St NE Washington DC 20001
#   -> Attempting to geocode: 1636 East Capital St NE Washington DC 20001
#   -> Geocoder returned None for: 1636 East Capital St NE Washington DC 20001
#
# Processing 66/924: Attn: Walker Mill Community Development Center 6801 Walker Mill Rd Capitol Heights MD 20743
#   -> Attempting to geocode: 6801 Walker Mill Rd Capitol Heights MD 20743
#
# Processing 67/924: Attn: Bethlehem Baptist Church 7836 Fordson Road Alexandria VA 22306
#   -> Attempting to geocode: 7836 Fordson Road Alexandria VA 22306
#   -> Geocoder returned None for: 7836 Fordson Road Alexandria VA 22306
#
# Processing 68/924: Attn: St. Joseph Catholic Church 2020 St Joseph Drive  Largo MD 20774
#   -> Attempting to geocode: 2020 St Joseph Drive Largo MD 20774
#   -> Geocoder returned None for: 2020 St Joseph Drive Largo MD 20774
#
# Processing 69/924: Attn: Sowing Empowerment & Economic Development, Inc. 5819 Eastpine Dr Riverdale MD 20737
#   -> Attempting to geocode: 5819 Eastpine Dr Riverdale MD 20737
#
# Processing 70/924: Attn: Church of the Incarnation, St. Vincent De Paul Society 880 Eastern Ave  NE Washington DC 20019
#   -> Attempting to geocode: 880 Eastern Ave NE Washington DC 20019
#
# Processing 71/924: Attn: Capital Christian Fellowship 10411 Greenbelt Rd  Lanham MD 20706
#   -> Attempting to geocode: 10411 Greenbelt Rd Lanham MD 20706
#   -> Geocoder returned None for: 10411 Greenbelt Rd Lanham MD 20706
#
# Processing 72/924: Attn: Grace Ministries - Culmore 5901 Leesburg Pike Falls Church VA 22041
#   -> Attempting to geocode: 5901 Leesburg Pike Falls Church VA 22041
#   -> Geocoder returned None for: 5901 Leesburg Pike Falls Church VA 22041
#
# Processing 73/924: Attn: Divine Grace Mission 4208 Glenn Dale Rd Bowie MD 20720
#   -> Attempting to geocode: 4208 Glenn Dale Rd Bowie MD 20720
#   -> Geocoder returned None for: 4208 Glenn Dale Rd Bowie MD 20720
#
# Processing 74/924: Attn: Divine Grace Mission 4208 Glenn Dale Rd Bowie MD 20720
#   -> Attempting to geocode: 4208 Glenn Dale Rd Bowie MD 20720
#   -> Geocoder returned None for: 4208 Glenn Dale Rd Bowie MD 20720
#
# Processing 75/924: Attn: Bull Run Unitarian Universalists 9350 Main Street Manassas VA 20110
#   -> Attempting to geocode: 9350 Main Street Manassas VA 20110
#
# Processing 76/924: Attn: St. Thomas United Methodist Church 8899 Sudley Road Manassas VA 20110
#   -> Attempting to geocode: 8899 Sudley Road Manassas VA 20110
#
# Processing 77/924: Attn: RCCG New Wine Assembly 1625 Olive Street NE Washington DC 20019
#   -> Attempting to geocode: 1625 Olive Street NE Washington DC 20019
#
# Processing 78/924: Attn: National Baptist Memorial Church 1501 Columbia Rd NW Washington DC 20009
#   -> Attempting to geocode: 1501 Columbia Rd NW Washington DC 20009
#
# Processing 79/924: Attn: St. Paul's Lutheran Church 4900 Connecticut Ave NW  Washington DC  20008
#   -> Attempting to geocode: 4900 Connecticut Ave NW Washington DC 20008
#
# Processing 80/924: Attn: Little David Baptist Church 3103 Shepherd Street Mount Rainier MD 20712
#   -> Attempting to geocode: 3103 Shepherd Street Mount Rainier MD 20712
#
# Processing 81/924: Attn: Little David Baptist Church 3103 Shepherd Street Mount Rainier MD 20712
#   -> Attempting to geocode: 3103 Shepherd Street Mount Rainier MD 20712
#
# Processing 82/924: Attn: Mount Ennon Baptist Church 9832 Piscataway Road Clinton MD 20735
#   -> Attempting to geocode: 9832 Piscataway Road Clinton MD 20735
#
# Processing 83/924: Attn: Mount Ennon Baptist Church 9832 Piscataway Road Clinton MD 20735
#   -> Attempting to geocode: 9832 Piscataway Road Clinton MD 20735
#
# Processing 84/924: Attn: Koinonia Foundation, Inc. 6037 Franconia Road Alexandria VA 22310
#   -> Attempting to geocode: 6037 Franconia Road Alexandria VA 22310
#   -> Geocoder returned None for: 6037 Franconia Road Alexandria VA 22310
#
# Processing 85/924: Attn: Koinonia Foundation, Inc. 6037 Franconia Road Alexandria VA 22310
#   -> Attempting to geocode: 6037 Franconia Road Alexandria VA 22310
#   -> Geocoder returned None for: 6037 Franconia Road Alexandria VA 22310
#
# Processing 86/924: Attn: Koinonia Foundation, Inc. 6037 Franconia Road Alexandria VA 22310
#   -> Attempting to geocode: 6037 Franconia Road Alexandria VA 22310
#   -> Geocoder returned None for: 6037 Franconia Road Alexandria VA 22310
#
# Processing 87/924: Attn: Koinonia Foundation, Inc. 6037 Franconia Road Alexandria VA 22310
#   -> Attempting to geocode: 6037 Franconia Road Alexandria VA 22310
#   -> Geocoder returned None for: 6037 Franconia Road Alexandria VA 22310
#
# Processing 88/924: Attn: Koinonia Foundation, Inc. 6037 Franconia Road Alexandria VA 22310
#   -> Attempting to geocode: 6037 Franconia Road Alexandria VA 22310
#   -> Geocoder returned None for: 6037 Franconia Road Alexandria VA 22310
#
# Processing 89/924: Attn: Koinonia Foundation, Inc. 6037 Franconia Road Alexandria VA 22310
#   -> Attempting to geocode: 6037 Franconia Road Alexandria VA 22310
#   -> Geocoder returned None for: 6037 Franconia Road Alexandria VA 22310
#
# Processing 90/924: Attn: Marlboro Churches Food Bank 4610 Largo Rd. Upper Marlboro MD 20772
#   -> Attempting to geocode: 4610 Largo Rd. Upper Marlboro MD 20772
#   -> Geocoder returned None for: 4610 Largo Rd. Upper Marlboro MD 20772
#
# Processing 91/924: Attn: Iglesia Pentecostal Trono de Jehova 2260 York Drive Woodbridge VA 22191
#   -> Attempting to geocode: 2260 York Drive Woodbridge VA 22191
#
# Processing 92/924: Attn: Our Lady Queen of Peace Church 2700 19th Street South Arlington VA 22204
#   -> Attempting to geocode: 2700 19th Street South Arlington VA 22204
#
# Processing 93/924: Attn: Emory Beacon of Light, Inc. 6100 Georgia Avenue NW  Washington  DC 20011
#   -> Attempting to geocode: 6100 Georgia Avenue NW Washington DC 20011
#
# Processing 94/924: Attn: Sterling United Methodist Church 304 East Church Road Sterling VA 20164
#   -> Attempting to geocode: 304 East Church Road Sterling VA 20164
#
# Processing 95/924: Attn: St. Anne's Episcopal Church ( Food Pantry) 1700 Wainwright Drive Reston VA 20190
#   -> Attempting to geocode: 1700 Wainwright Drive Reston VA 20190
#   -> Geocoder returned None for: 1700 Wainwright Drive Reston VA 20190
#
# Processing 96/924: Attn: New Macedonia Baptist Church 4115 Alabama Ave SE  Washington DC 20019
#   -> Attempting to geocode: 4115 Alabama Ave SE Washington DC 20019
#
# Processing 97/924: Attn: New Samaritan Baptist Church 1100 Florida Ave NE Washington DC 20002
#   -> Attempting to geocode: 1100 Florida Ave NE Washington DC 20002
#
# Processing 98/924: James V. Myers, JR 7929 Richmond Highway Alexandria VA 22306-
#   -> Attempting to geocode: 7929 Richmond Highway Alexandria VA 22306-
#
# Processing 99/924: Attn: Royal Missionary Baptist Church 8631 Engleside Office Park Alexandria VA 22309
#   -> Attempting to geocode: 8631 Engleside Office Park Alexandria VA 22309
#   -> Geocoder returned None for: 8631 Engleside Office Park Alexandria VA 22309
#
# Processing 100/924: Attn: Royal Missionary Baptist Church 8631 Engleside Office Park Alexandria VA 22309
#   -> Attempting to geocode: 8631 Engleside Office Park Alexandria VA 22309
#   -> Geocoder returned None for: 8631 Engleside Office Park Alexandria VA 22309
#
# Processing 101/924: Attn: Prince Emmanuel All Nations SDA Church 1925 Mitchellville Rd Bowie MD 20716
#   -> Attempting to geocode: 1925 Mitchellville Rd Bowie MD 20716
#
# Processing 102/924: Attn: St. Stephen's Baptist Church 5757 Temple Hill Road Camp Springs MD 20748
#   -> Attempting to geocode: 5757 Temple Hill Road Camp Springs MD 20748
#
# Processing 103/924: Attn: Breath of Life SDA Church 11310 Fort Washington Road Fort Washington MD 20744
#   -> Attempting to geocode: 11310 Fort Washington Road Fort Washington MD 20744
#
# Processing 104/924: Attn: Apostolic Church Glorious Vision 3004 Enterprise Road Bowie MD 20721
#   -> Attempting to geocode: 3004 Enterprise Road Bowie MD 20721
#   -> Geocoder returned None for: 3004 Enterprise Road Bowie MD 20721
#
# Processing 105/924: Attn: Bethesda Help 10100 Old Georgetown Road Bethesda MD 20814
#   -> Attempting to geocode: 10100 Old Georgetown Road Bethesda MD 20814
#
# Processing 106/924: Attn: Bethesda Help 10100 Old Georgetown Road Bethesda MD 20814
#   -> Attempting to geocode: 10100 Old Georgetown Road Bethesda MD 20814
#
# Processing 107/924: Attn: Bethesda Help 10100 Old Georgetown Road Bethesda MD 20814
#   -> Attempting to geocode: 10100 Old Georgetown Road Bethesda MD 20814
#
# Processing 108/924: Attn: Bethesda Help 10100 Old Georgetown Road Bethesda MD 20814
#   -> Attempting to geocode: 10100 Old Georgetown Road Bethesda MD 20814
#
# Processing 109/924: Attn: Bethesda Help 10100 Old Georgetown Road Bethesda MD 20814
#   -> Attempting to geocode: 10100 Old Georgetown Road Bethesda MD 20814
#
# Processing 110/924: Attn: Turner AME 7201 16th Place Hyattsville MD 20783
#   -> Attempting to geocode: 7201 16th Place Hyattsville MD 20783
#   -> Geocoder returned None for: 7201 16th Place Hyattsville MD 20783
#
# Processing 111/924: Attn: St. Jude Catholic Church 12701 Veirs Mill Rockville MD 20853
#   -> Attempting to geocode: 12701 Veirs Mill Rockville MD 20853
#
# Processing 112/924: Attn: Jamil-UL Jalil 10845 Lanham Severn Road Glenn Dale MD 20769
#   -> Attempting to geocode: 10845 Lanham Severn Road Glenn Dale MD 20769
#
# Processing 113/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 114/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 115/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 116/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 117/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 118/924: Attn: Christ United Methodist 900 4th Street SW Washington, DC 20024 Washington DC 20024
#   -> Attempting to geocode: 900 4th Street SW Washington, DC 20024 Washington DC 20024
#   -> Geocoder returned None for: 900 4th Street SW Washington, DC 20024 Washington DC 20024
#
# Processing 119/924: Attn: Lutheran Church of the Abiding Presence 6304 Lee Chapel Rd Burke VA 22015
#   -> Attempting to geocode: 6304 Lee Chapel Rd Burke VA 22015
#
# Processing 120/924: Attn: Loaves & Fishes 1525 Newton St NW Washington DC 20910
#   -> Attempting to geocode: 1525 Newton St NW Washington DC 20910
#
# Processing 121/924: Attn: Northern Virginia Food Rescue 10535 Battleview Pkwy Manassas VA 20110
#   -> Attempting to geocode: 10535 Battleview Pkwy Manassas VA 20110
#   -> Geocoder returned None for: 10535 Battleview Pkwy Manassas VA 20110
#
# Processing 122/924: Attn: Northern Virginia Food Rescue 10535 Battleview Pkwy Manassas VA 20110
#   -> Attempting to geocode: 10535 Battleview Pkwy Manassas VA 20110
#   -> Geocoder returned None for: 10535 Battleview Pkwy Manassas VA 20110
#
# Processing 123/924: Attn: Northern Virginia Food Rescue 10535 Battleview Pkwy Manassas VA 20110
#   -> Attempting to geocode: 10535 Battleview Pkwy Manassas VA 20110
#   -> Geocoder returned None for: 10535 Battleview Pkwy Manassas VA 20110
#
# Processing 124/924: Attn: Northern Virginia Food Rescue 10535 Battleview Pkwy Manassas VA 20110
#   -> Attempting to geocode: 10535 Battleview Pkwy Manassas VA 20110
#   -> Geocoder returned None for: 10535 Battleview Pkwy Manassas VA 20110
#
# Processing 125/924: Attn: Northern Virginia Food Rescue 10535 Battleview Pkwy Manassas VA 20110
#   -> Attempting to geocode: 10535 Battleview Pkwy Manassas VA 20110
#   -> Geocoder returned None for: 10535 Battleview Pkwy Manassas VA 20110
#
# Processing 126/924: Attn: The Redeemed Christian Church of God - Victory Temple 7218 Lockport Place Lorton VA 22079
#   -> Attempting to geocode: 7218 Lockport Place Lorton VA 22079
#   -> Geocoder returned None for: 7218 Lockport Place Lorton VA 22079
#
# Processing 127/924: Attn: Love Donation Pantry 3450 Laurel Fort Meade Rd. Suite 101 Laurel MD 20708
#   -> Attempting to geocode: 3450 Laurel Fort Meade Rd. Suite 101 Laurel MD 20708
#   -> Geocoder returned None for: 3450 Laurel Fort Meade Rd. Suite 101 Laurel MD 20708
#
# Processing 128/924: Attn: The Hope Association 80 Mst SE Washington DC DC 20003
#   -> Attempting to geocode: 80 Mst SE Washington DC DC 20003
#   -> Geocoder returned None for: 80 Mst SE Washington DC DC 20003
#
# Processing 129/924: Attn: Wells Robertson House 1 Wells Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 1 Wells Ave Gaithersburg MD 20877
#
# Processing 130/924: Attn: Wells Robertson House 1 Wells Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 1 Wells Ave Gaithersburg MD 20877
#
# Processing 131/924: Attn: Wells Robertson House 1 Wells Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 1 Wells Ave Gaithersburg MD 20877
#
# Processing 132/924: Attn: Wells Robertson House 1 Wells Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 1 Wells Ave Gaithersburg MD 20877
#
# Processing 133/924: Attn: Wells Robertson House 1 Wells Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 1 Wells Ave Gaithersburg MD 20877
#
# Processing 134/924: Attn: Wells Robertson House 1 Wells Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 1 Wells Ave Gaithersburg MD 20877
#
# Processing 135/924: Attn: Wells Robertson House 1 Wells Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 1 Wells Ave Gaithersburg MD 20877
#
# Processing 136/924: Attn:  Food & Clothing Center of Ward 7 (Peace Lutheran Church) 4929 Ames St NE Washington  DC 20019
#   -> Attempting to geocode: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#   -> Geocoder returned None for: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#
# Processing 137/924: Attn:  Food & Clothing Center of Ward 7 (Peace Lutheran Church) 4929 Ames St NE Washington  DC 20019
#   -> Attempting to geocode: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#   -> Geocoder returned None for: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#
# Processing 138/924: Attn:  Food & Clothing Center of Ward 7 (Peace Lutheran Church) 4929 Ames St NE Washington  DC 20019
#   -> Attempting to geocode: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#   -> Geocoder returned None for: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#
# Processing 139/924: Attn:  Food & Clothing Center of Ward 7 (Peace Lutheran Church) 4929 Ames St NE Washington  DC 20019
#   -> Attempting to geocode: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#   -> Geocoder returned None for: 7 (Peace Lutheran Church) 4929 Ames St NE Washington DC 20019
#
# Processing 140/924: Attn: New Hope Housing Kennedy 9155 Richmond Hwy Fort Belvoir VA 22060
#   -> Attempting to geocode: 9155 Richmond Hwy Fort Belvoir VA 22060
#
# Processing 141/924: Attn: New Hope Housing Kennedy 9155 Richmond Hwy Fort Belvoir VA 22060
#   -> Attempting to geocode: 9155 Richmond Hwy Fort Belvoir VA 22060
#
# Processing 142/924: Attn: New Hope Housing Kennedy 9155 Richmond Hwy Fort Belvoir VA 22060
#   -> Attempting to geocode: 9155 Richmond Hwy Fort Belvoir VA 22060
#
# Processing 143/924: Attn: New Hope Housing Kennedy 9155 Richmond Hwy Fort Belvoir VA 22060
#   -> Attempting to geocode: 9155 Richmond Hwy Fort Belvoir VA 22060
#
# Processing 144/924: Attn: New Hope Housing Kennedy 9155 Richmond Hwy Fort Belvoir VA 22060
#   -> Attempting to geocode: 9155 Richmond Hwy Fort Belvoir VA 22060
#
# Processing 145/924: Attn: New Hope Housing Kennedy 9155 Richmond Hwy Fort Belvoir VA 22060
#   -> Attempting to geocode: 9155 Richmond Hwy Fort Belvoir VA 22060
#
# Processing 146/924: Attn: New Hope Housing Kennedy 9155 Richmond Hwy Fort Belvoir VA 22060
#   -> Attempting to geocode: 9155 Richmond Hwy Fort Belvoir VA 22060
#
# Processing 147/924: Attn: Mount Rainier Seventh Day Adventist Spanish Chuch 6012 Ager Road Hyattsville MD 20782
#   -> Attempting to geocode: 6012 Ager Road Hyattsville MD 20782
#
# Processing 148/924: Attn: Mount Rainier Seventh Day Adventist Spanish Chuch 6012 Ager Road Hyattsville MD 20782
#   -> Attempting to geocode: 6012 Ager Road Hyattsville MD 20782
#
# Processing 149/924: Attn: SevaTruck Foundation 2815 Old Lee Hwy Fairfax Fairfax VA 22031
#   -> Attempting to geocode: 2815 Old Lee Hwy Fairfax Fairfax VA 22031
#
# Processing 150/924: Community Multi-Service 6300 9th St NW  Washington DC  DC 20011
#   -> Attempting to geocode: 6300 9th St NW Washington DC DC 20011
#
# Processing 151/924: Attn: Central Baptist Church of Camp Springs 5600 Old Branch Avenue Camp Springs MD 20748
#   -> Attempting to geocode: 5600 Old Branch Avenue Camp Springs MD 20748
#
# Processing 152/924: Attn: Central Baptist Church of Camp Springs 5600 Old Branch Avenue Camp Springs MD 20748
#   -> Attempting to geocode: 5600 Old Branch Avenue Camp Springs MD 20748
#
# Processing 153/924: Attn: Central Baptist Church of Camp Springs 5600 Old Branch Avenue Camp Springs MD 20748
#   -> Attempting to geocode: 5600 Old Branch Avenue Camp Springs MD 20748
#
# Processing 154/924: Attn: Purity Baptist Church 1325 Maryland Ave NE Washington DC 20002
#   -> Attempting to geocode: 1325 Maryland Ave NE Washington DC 20002
#
# Processing 155/924: Attn: National City Christian Church 5 Thomas Circle NW Washington DC 20005
#   -> Attempting to geocode: 5 Thomas Circle NW Washington DC 20005
#
# Processing 156/924: Attn: Good Samaritan Ministry 1417 Chillum Rd Hyattsville MD 20782
#   -> Attempting to geocode: 1417 Chillum Rd Hyattsville MD 20782
#   -> Geocoder returned None for: 1417 Chillum Rd Hyattsville MD 20782
#
# Processing 157/924: Attn: Covenant Baptist Food Pantry 3845 South Capitol St SW Washington DC 20032
#   -> Attempting to geocode: 3845 South Capitol St SW Washington DC 20032
#
# Processing 158/924: Attn: Nineteenth Street Baptist Church 4606 16th St NW Washington DC 20011
#   -> Attempting to geocode: 4606 16th St NW Washington DC 20011
#
# Processing 159/924: Attn: First Baptist Church of Capitol Heights 6 Capitol Heights Blvd Capitol Heights MD 20743
#   -> Attempting to geocode: 6 Capitol Heights Blvd Capitol Heights MD 20743
#
# Processing 160/924: Attn: First Baptist Church of Capitol Heights 6 Capitol Heights Blvd Capitol Heights MD 20743
#   -> Attempting to geocode: 6 Capitol Heights Blvd Capitol Heights MD 20743
#
# Processing 161/924: Attn: Assumption Outreach 220 Highview Place SE  Washington DC 20032
#   -> Attempting to geocode: 220 Highview Place SE Washington DC 20032
#
# Processing 162/924: Attn: Assumption Outreach 220 Highview Place SE  Washington DC 20032
#   -> Attempting to geocode: 220 Highview Place SE Washington DC 20032
#
# Processing 163/924: Attn: Assumption Outreach 220 Highview Place SE  Washington DC 20032
#   -> Attempting to geocode: 220 Highview Place SE Washington DC 20032
#
# Processing 164/924: Attn: Metropolitan SDA Church 6303 Riggs Rd Hyattsville MD 20783
#   -> Attempting to geocode: 6303 Riggs Rd Hyattsville MD 20783
#   -> Geocoder returned None for: 6303 Riggs Rd Hyattsville MD 20783
#
# Processing 165/924: Attn: Church of Christ of Dale City 13130 Hillendale Drive Dale City VA 22193
#   -> Attempting to geocode: 13130 Hillendale Drive Dale City VA 22193
#   -> Geocoder returned None for: 13130 Hillendale Drive Dale City VA 22193
#
# Processing 166/924: Attn: Food For All 1810 16th St NW Washington DC 20009
#   -> Attempting to geocode: 1810 16th St NW Washington DC 20009
#
# Processing 167/924: Attn: Food For All 1810 16th St NW Washington DC 20009
#   -> Attempting to geocode: 1810 16th St NW Washington DC 20009
#
# Processing 168/924: Attn: Food For All 1810 16th St NW Washington DC 20009
#   -> Attempting to geocode: 1810 16th St NW Washington DC 20009
#
# Processing 169/924: Attn: Food For All 1810 16th St NW Washington DC 20009
#   -> Attempting to geocode: 1810 16th St NW Washington DC 20009
#
# Processing 170/924: Attn: Food For All 1810 16th St NW Washington DC 20009
#   -> Attempting to geocode: 1810 16th St NW Washington DC 20009
#
# Processing 171/924: Attn: Fort Foote Baptist Church 8310 Fort Foot Road Fort Washington MD 20744
#   -> Attempting to geocode: 8310 Fort Foot Road Fort Washington MD 20744
#   -> Geocoder returned None for: 8310 Fort Foot Road Fort Washington MD 20744
#
# Processing 172/924: Attn: Our Lady of Perpetual Help Church 1600 Morris Rd SE Washington DC 20020
#   -> Attempting to geocode: 1600 Morris Rd SE Washington DC 20020
#
# Processing 173/924: Attn: Fort Washington Food Pantry 9801 Livingston Road Fort Washington MD 20744
#   -> Attempting to geocode: 9801 Livingston Road Fort Washington MD 20744
#
# Processing 174/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 175/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 176/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 177/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 178/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 179/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 180/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 181/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 182/924: Attn: WFCM Food Pantry 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Attempting to geocode: 4511 Daly Dr Suite J Chantilly VA 20151
#   -> Geocoder returned None for: 4511 Daly Dr Suite J Chantilly VA 20151
#
# Processing 183/924: Attn: Washington Spanish SDA Church 12604 New Hampshire Avenue Silver Spring MD 20904
#   -> Attempting to geocode: 12604 New Hampshire Avenue Silver Spring MD 20904
#
# Processing 184/924: Attn: Gethsemane United Methodist Church 910 Addison Road Capitol Heights MD 20743
#   -> Attempting to geocode: 910 Addison Road Capitol Heights MD 20743
#
# Processing 185/924: Attn: Bread & Fishes 3890 Cameron Street Dumfries Va 22026
#   -> Attempting to geocode: 3890 Cameron Street Dumfries Va 22026
#
# Processing 186/924: Attn: Urban Outreach Inc. 5343 C St SE  Suite 204 Washington DC 20019
#   -> Attempting to geocode: 5343 C St SE Suite 204 Washington DC 20019
#   -> Geocoder returned None for: 5343 C St SE Suite 204 Washington DC 20019
#
# Processing 187/924: Attn: Greater Fellowship Missionary Baptist Church 814 Alabama Ave SE Washington DC 20032
#   -> Attempting to geocode: 814 Alabama Ave SE Washington DC 20032
#
# Processing 188/924: Attn: Prince George's County DSS 805 Brightseat Rd Landover MD 20785
#   -> Attempting to geocode: 805 Brightseat Rd Landover MD 20785
#
# Processing 189/924: Attn: Prince George's County DSS 805 Brightseat Rd Landover MD 20785
#   -> Attempting to geocode: 805 Brightseat Rd Landover MD 20785
#
# Processing 190/924: Attn: Prince George's County DSS 805 Brightseat Rd Landover MD 20785
#   -> Attempting to geocode: 805 Brightseat Rd Landover MD 20785
#
# Processing 191/924: Attn: Prince George's County DSS 805 Brightseat Rd Landover MD 20785
#   -> Attempting to geocode: 805 Brightseat Rd Landover MD 20785
#
# Processing 192/924: Attn: Prince George's County DSS 805 Brightseat Rd Landover MD 20785
#   -> Attempting to geocode: 805 Brightseat Rd Landover MD 20785
#
# Processing 193/924: Attn: St. Paul UMC 6634 St. Barnabas Road Oxon Hill  MD 20745
#   -> Attempting to geocode: 6634 St. Barnabas Road Oxon Hill MD 20745
#
# Processing 194/924: Attn: St. Margaret of Scotland Catholic Church 408 Addison Road, South Capitol Heights MD 20743
#   -> Attempting to geocode: 408 Addison Road, South Capitol Heights MD 20743
#   -> Geocoder returned None for: 408 Addison Road, South Capitol Heights MD 20743
#
# Processing 195/924: Attn: FISH of Laurel, Inc. 308 Gorman Ave Laurel  MD 20707
#   -> Attempting to geocode: 308 Gorman Ave Laurel MD 20707
#
# Processing 196/924: Attn: FISH of Laurel, Inc. 308 Gorman Ave Laurel  MD 20707
#   -> Attempting to geocode: 308 Gorman Ave Laurel MD 20707
#
# Processing 197/924: Attn: Life Builders 6608 Wilkins Place Forestville MD 20747
#   -> Attempting to geocode: 6608 Wilkins Place Forestville MD 20747
#
# Processing 198/924: Attn: Victory Drug Center 1804 Quarter Avenue Capitol Heights MD 20743
#   -> Attempting to geocode: 1804 Quarter Avenue Capitol Heights MD 20743
#   -> Geocoder returned None for: 1804 Quarter Avenue Capitol Heights MD 20743
#
# Processing 199/924: Attn: Capital Christian Fellowship 10411 Greenbelt Rd  Lanham MD 20706
#   -> Attempting to geocode: 10411 Greenbelt Rd Lanham MD 20706
#   -> Geocoder returned None for: 10411 Greenbelt Rd Lanham MD 20706
#
# Processing 200/924: Attn: St. Paul United Methodist Church 1400 G St Woodbridge  VA 22191
#   -> Attempting to geocode: 1400 G St Woodbridge VA 22191
#
# Processing 201/924: Attn: St. Paul United Methodist Church 1400 G St Woodbridge  VA 22191
#   -> Attempting to geocode: 1400 G St Woodbridge VA 22191
#
# Processing 202/924: Attn: Woodlawn United Methodist Church 7730 Fordson Road Alexandria VA 22306
#   -> Attempting to geocode: 7730 Fordson Road Alexandria VA 22306
#   -> Geocoder returned None for: 7730 Fordson Road Alexandria VA 22306
#
# Processing 203/924: Attn: Floris United Methodist Church 13600 Frying Pan Road Herndon VA 20171
#   -> Attempting to geocode: 13600 Frying Pan Road Herndon VA 20171
#   -> Geocoder returned None for: 13600 Frying Pan Road Herndon VA 20171
#
# Processing 204/924: Attn: Galilee Community Development Corporation 2101 Shadyside Ave  Suitland MD  20746
#   -> Attempting to geocode: 2101 Shadyside Ave Suitland MD 20746
#
# Processing 205/924: Attn: Galilee Community Development Corporation 2101 Shadyside Ave  Suitland MD  20746
#   -> Attempting to geocode: 2101 Shadyside Ave Suitland MD 20746
#
# Processing 206/924: Attn: Galilee Community Development Corporation 2101 Shadyside Ave  Suitland MD  20746
#   -> Attempting to geocode: 2101 Shadyside Ave Suitland MD 20746
#
# Processing 207/924: Angela Wilson 5340 Baltimore Ave Hyattsville MD 20781
#   -> Attempting to geocode: 5340 Baltimore Ave Hyattsville MD 20781
#
# Processing 208/924: Attn: Luther Rice Neighborhood Center 801 University Blvd W Silver Spring MD 20901
#   -> Attempting to geocode: 801 University Blvd W Silver Spring MD 20901
#
# Processing 209/924: Attn: Sydenstricker UMC 8508 Hooes Road Springfield VA 22153
#   -> Attempting to geocode: 8508 Hooes Road Springfield VA 22153
#   -> Geocoder returned None for: 8508 Hooes Road Springfield VA 22153
#
# Processing 210/924: Attn: Clothing of Power Eternal Church 25 Quire Ave Capitol Heights MD 20743
#   -> Attempting to geocode: 25 Quire Ave Capitol Heights MD 20743
#
# Processing 211/924: Attn: Emmanuel UMC 11416 Cedar Lane Beltsville MD 20705
#   -> Attempting to geocode: 11416 Cedar Lane Beltsville MD 20705
#
# Processing 212/924: Attn: Catholic Charities - CHRIST HOUSE 4725A Eisenhower Avenue ALEXANDRIA VA 22304
#   -> Attempting to geocode: 4725A Eisenhower Avenue ALEXANDRIA VA 22304
#
# Processing 213/924: Attn: Catholic Charities - CHRIST HOUSE 4725A Eisenhower Avenue ALEXANDRIA VA 22304
#   -> Attempting to geocode: 4725A Eisenhower Avenue ALEXANDRIA VA 22304
#
# Processing 214/924: Attn: St. Stephen's UMC 9203 Braddock Rd  Burke  VA 22015
#   -> Attempting to geocode: 9203 Braddock Rd Burke VA 22015
#   -> Geocoder returned None for: 9203 Braddock Rd Burke VA 22015
#
# Processing 215/924: Attn: St. Camillus Catholic Church 1600 Saint Camillus Drive  Silver Spring MD 20903
#   -> Attempting to geocode: 1600 Saint Camillus Drive Silver Spring MD 20903
#
# Processing 216/924: Attn: St. Camillus Catholic Church 1600 Saint Camillus Drive  Silver Spring MD 20903
#   -> Attempting to geocode: 1600 Saint Camillus Drive Silver Spring MD 20903
#
# Processing 217/924: Attn: Great Commission Change of Life Ministries 7937 Penn Randall Place Unit A Upper Marlboro  MD 20772
#   -> Attempting to geocode: 7937 Penn Randall Place Unit A Upper Marlboro MD 20772
#   -> Geocoder returned None for: 7937 Penn Randall Place Unit A Upper Marlboro MD 20772
#
# Processing 218/924: Attn: Faith Social Services 795 Center St #2A Herndon VA 20170
#   -> Attempting to geocode: 795 Center St #2A Herndon VA 20170
#   -> Geocoder returned None for: 795 Center St #2A Herndon VA 20170
#
# Processing 219/924: Attn: Faith Social Services 795 Center St #2A Herndon VA 20170
#   -> Attempting to geocode: 795 Center St #2A Herndon VA 20170
#   -> Geocoder returned None for: 795 Center St #2A Herndon VA 20170
#
# Processing 220/924: Attn: Faith Social Services 795 Center St #2A Herndon VA 20170
#   -> Attempting to geocode: 795 Center St #2A Herndon VA 20170
#   -> Geocoder returned None for: 795 Center St #2A Herndon VA 20170
#
# Processing 221/924: Attn: Faith Social Services 795 Center St #2A Herndon VA 20170
#   -> Attempting to geocode: 795 Center St #2A Herndon VA 20170
#   -> Geocoder returned None for: 795 Center St #2A Herndon VA 20170
#
# Processing 222/924: Attn: Holiness Tabernacle P.O. Box 2193 Dale City VA 22195
#   -> Attempting to geocode: 2193 Dale City VA 22195
#
# Processing 223/924: Attn: Allen Chapel AME Church Outreach Ministry 2518 Fairland Road Silver Spring MD 20904
#   -> Attempting to geocode: 2518 Fairland Road Silver Spring MD 20904
#
# Processing 224/924: Attn: Allen Chapel AME Church Outreach Ministry 2518 Fairland Road Silver Spring MD 20904
#   -> Attempting to geocode: 2518 Fairland Road Silver Spring MD 20904
#
# Processing 225/924: Attn: Marlboro Churches Food Bank 4610 Largo Rd. Upper Marlboro MD 20772
#   -> Attempting to geocode: 4610 Largo Rd. Upper Marlboro MD 20772
#   -> Geocoder returned None for: 4610 Largo Rd. Upper Marlboro MD 20772
#
# Processing 226/924: Attn: Dar Al-Hijrah Islamic Center 3159 Row Street Falls Church VA 22044
#   -> Attempting to geocode: 3159 Row Street Falls Church VA 22044
#   -> Geocoder returned None for: 3159 Row Street Falls Church VA 22044
#
# Processing 227/924: Attn: Gospel Assembly Church 8740-12 Cherry Lane Laurel MD 20707
#   -> Attempting to geocode: 8740-12 Cherry Lane Laurel MD 20707
#   -> Geocoder returned None for: 8740-12 Cherry Lane Laurel MD 20707
#
# Processing 228/924: Attn: Gospel Assembly Church 8740-12 Cherry Lane Laurel MD 20707
#   -> Attempting to geocode: 8740-12 Cherry Lane Laurel MD 20707
#   -> Geocoder returned None for: 8740-12 Cherry Lane Laurel MD 20707
#
# Processing 229/924: Attn: Restoration Center 119 Centerway Dr. Greenbelt MD 20770
#   -> Attempting to geocode: 119 Centerway Dr. Greenbelt MD 20770
#   -> Geocoder returned None for: 119 Centerway Dr. Greenbelt MD 20770
#
# Processing 230/924: Attn: Restoration Center 119 Centerway Dr. Greenbelt MD 20770
#   -> Attempting to geocode: 119 Centerway Dr. Greenbelt MD 20770
#   -> Geocoder returned None for: 119 Centerway Dr. Greenbelt MD 20770
#
# Processing 231/924: Attn: Clifton Park Baptist Church 8818 Piney Branch Rd Silver Spring MD 20903
#   -> Attempting to geocode: 8818 Piney Branch Rd Silver Spring MD 20903
#
# Processing 232/924: Attn: Clifton Park Baptist Church 8818 Piney Branch Rd Silver Spring MD 20903
#   -> Attempting to geocode: 8818 Piney Branch Rd Silver Spring MD 20903
#
# Processing 233/924: Attn: Clifton Park Baptist Church 8818 Piney Branch Rd Silver Spring MD 20903
#   -> Attempting to geocode: 8818 Piney Branch Rd Silver Spring MD 20903
#
# Processing 234/924: Attn: Oxon Hill Church of Christ 4201 Brinkley Road Temple Hills MD 20748
#   -> Attempting to geocode: 4201 Brinkley Road Temple Hills MD 20748
#
# Processing 235/924: Attn: Beltsville Adventist Community Center 4200 Ammendale Rd. Beltsville MD 20705
#   -> Attempting to geocode: 4200 Ammendale Rd. Beltsville MD 20705
#
# Processing 236/924: Attn: Beltsville Adventist Community Center 4200 Ammendale Rd. Beltsville MD 20705
#   -> Attempting to geocode: 4200 Ammendale Rd. Beltsville MD 20705
#
# Processing 237/924: Attn: Beltsville Adventist Community Center 4200 Ammendale Rd. Beltsville MD 20705
#   -> Attempting to geocode: 4200 Ammendale Rd. Beltsville MD 20705
#
# Processing 238/924: Attn: Springfield Christian Church 5407 Backlick Rd Springfield VA 22151
#   -> Attempting to geocode: 5407 Backlick Rd Springfield VA 22151
#
# Processing 239/924: Attn: Montgomery County Muslim Foundation 11 Park Ave Gaithersburg MD 20877
#   -> Attempting to geocode: 11 Park Ave Gaithersburg MD 20877
#
# Processing 240/924: Attn: Mt. Calvary Catholic Church, Ladies of Charity Food Pantry 6706 Marlboro Pike Forestville MD 20747
#   -> Attempting to geocode: 6706 Marlboro Pike Forestville MD 20747
#
# Processing 241/924: Attn: This Generation Ministries 9470 Annapolis Rd Suite 407 Lanham MD 20706
#   -> Attempting to geocode: 9470 Annapolis Rd Suite 407 Lanham MD 20706
#   -> Geocoder returned None for: 9470 Annapolis Rd Suite 407 Lanham MD 20706
#
# Processing 242/924: Attn: Groveton Baptist Church 6511 Richmond Highway  Alexandria VA 22306
#   -> Attempting to geocode: 6511 Richmond Highway Alexandria VA 22306
#
# Processing 243/924: Attn: Salvation Army Arlington Corps 518 S. Glebe Rd Arlington VA 22204
#   -> Attempting to geocode: 518 S. Glebe Rd Arlington VA 22204
#
# Processing 244/924: Attn: Salvation Army Arlington Corps 518 S. Glebe Rd Arlington VA 22204
#   -> Attempting to geocode: 518 S. Glebe Rd Arlington VA 22204
#
# Processing 245/924: Attn: Mt. Jezreel Baptist Church 420 University Blvd East Silver Spring MD 20901
# ...
#
# Processing 843/924: Megan Joe 4924 wyaconda road  Rockville  MD 20852
#   -> Attempting to geocode: 4924 wyaconda road Rockville MD 20852
#   -> Geocoder returned None for: 4924 wyaconda road Rockville MD 20852
#
# Processing 844/924: Attn: Silver Spring Christian Reformed Church 1501 Arcola Ave Silver Spring MD 20902
#   -> Attempting to geocode: 1501 Arcola Ave Silver Spring MD 20902
#
# Processing 845/924: Attn: First Baptist Church of Highland Park 6801 Sheriff Road Landover MD 20785
#   -> Attempting to geocode: 6801 Sheriff Road Landover MD 20785
#
# Processing 846/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 847/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 848/924: Attn: Mother of Light Center 421 Clifford Ave Alexandria VA 22305
#   -> Attempting to geocode: 421 Clifford Ave Alexandria VA 22305
#
# Processing 849/924: Attn: The Family Place 3309 16th St NW Washington DC DC 20010
#   -> Attempting to geocode: 3309 16th St NW Washington DC DC 20010
#
# Processing 850/924: Attn: The Family Place 3309 16th St NW Washington DC DC 20010
#   -> Attempting to geocode: 3309 16th St NW Washington DC DC 20010
#
# Processing 851/924: Attn: The Family Place 3309 16th St NW Washington DC DC 20010
#   -> Attempting to geocode: 3309 16th St NW Washington DC DC 20010
#
# Processing 852/924: Attn: Women Who Care Ministries 19640 Club House Road Suite 410 Montgomery Villlage MD 20886
#   -> Attempting to geocode: 19640 Club House Road Suite 410 Montgomery Villlage MD 20886
#   -> Geocoder returned None for: 19640 Club House Road Suite 410 Montgomery Villlage MD 20886
#
# Processing 853/924: Attn: Montgomery County Family Center 12247 Georgia Ave. Silver Spring MD 20902
#   -> Attempting to geocode: 12247 Georgia Ave. Silver Spring MD 20902
#
# Processing 854/924: Attn: Oak Chapel UMC 14500 Layhill Road Silver Spring MD 20906
#   -> Attempting to geocode: 14500 Layhill Road Silver Spring MD 20906
#   -> Geocoder returned None for: 14500 Layhill Road Silver Spring MD 20906
#
# Processing 855/924: Attn: Mount Ennon Baptist Church 9832 Piscataway Road Clinton MD 20735
#   -> Attempting to geocode: 9832 Piscataway Road Clinton MD 20735
#
# Processing 856/924: Attn: Oak Chapel UMC 14500 Layhill Road Silver Spring MD 20906
#   -> Attempting to geocode: 14500 Layhill Road Silver Spring MD 20906
#   -> Geocoder returned None for: 14500 Layhill Road Silver Spring MD 20906
#
# Processing 857/924: Attn: Oak Chapel UMC 14500 Layhill Road Silver Spring MD 20906
#   -> Attempting to geocode: 14500 Layhill Road Silver Spring MD 20906
#   -> Geocoder returned None for: 14500 Layhill Road Silver Spring MD 20906
#
# Processing 858/924: Attn: Revival Baptist Ministries INT 8174 Richmond Hwy Alexandria VA 22309
#   -> Attempting to geocode: 8174 Richmond Hwy Alexandria VA 22309
#
# Processing 859/924: Attn: Manna Food Center 9311 Gaither Rd Gaithersburg MD 20877
#   -> Attempting to geocode: 9311 Gaither Rd Gaithersburg MD 20877
#
# Processing 860/924: Attn: Manna Food Center 9311 Gaither Rd Gaithersburg MD 20877
#   -> Attempting to geocode: 9311 Gaither Rd Gaithersburg MD 20877
#
# Processing 861/924: Attn: CAC Bethel Fellowship Church 7513 Northern Avenue Glenn Dale MD 20769
#   -> Attempting to geocode: 7513 Northern Avenue Glenn Dale MD 20769
#
# Processing 862/924: Attn: Central Union Mission 65 Massachusetts Ave Washington DC 20001
#   -> Attempting to geocode: 65 Massachusetts Ave Washington DC 20001
#
# Processing 863/924: Attn: Central Union Mission 65 Massachusetts Ave Washington DC 20001
#   -> Attempting to geocode: 65 Massachusetts Ave Washington DC 20001
#
# Processing 864/924: Attn: National Baptist Memorial Church 1501 Columbia Rd NW Washington DC 20009
#   -> Attempting to geocode: 1501 Columbia Rd NW Washington DC 20009
#
# Processing 865/924: Attn: National Baptist Memorial Church 1501 Columbia Rd NW Washington DC 20009
#   -> Attempting to geocode: 1501 Columbia Rd NW Washington DC 20009
#
# Processing 866/924: Attn: The Holy Temple Church of Christ, Inc. 439 12th. Street SE Washington DC 20003
#   -> Attempting to geocode: 439 12th. Street SE Washington DC 20003
#
# Processing 867/924: Attn: Faith Village of Greater Laurel, Inc. 13714 Briarwood Drive  Laurel MD 20708
#   -> Attempting to geocode: 13714 Briarwood Drive Laurel MD 20708
#
# Processing 868/924: Attn: Mount Ennon Baptist Church 9832 Piscataway Road Clinton MD 20735
#   -> Attempting to geocode: 9832 Piscataway Road Clinton MD 20735
#
# Processing 869/924: Attn: Operation Earnie's Plate 8500 Mike Shapiro Dr Clinton MD 20735
#   -> Attempting to geocode: 8500 Mike Shapiro Dr Clinton MD 20735
#   -> Geocoder returned None for: 8500 Mike Shapiro Dr Clinton MD 20735
#
# Processing 870/924: Attn: St. Paul UMC 6634 St. Barnabas Road Oxon Hill  MD 20745
#   -> Attempting to geocode: 6634 St. Barnabas Road Oxon Hill MD 20745
#
# Processing 871/924: Attn: Covenant Baptist Food Pantry 3845 South Capitol St SW Washington DC 20032
#   -> Attempting to geocode: 3845 South Capitol St SW Washington DC 20032
#
# Processing 872/924: Attn: Celestial Church of Chirst 1880 Adams Street NE Washington DC 20018
#   -> Attempting to geocode: 1880 Adams Street NE Washington DC 20018
#
# Processing 873/924: Attn: Harvest Intercontinental Church 16227 Batchellors Forest Rd Olney MD 20832
#   -> Attempting to geocode: 16227 Batchellors Forest Rd Olney MD 20832
#   -> Geocoder returned None for: 16227 Batchellors Forest Rd Olney MD 20832
#
# Processing 874/924: Attn: Harvest Intercontinental Church 16227 Batchellors Forest Rd Olney MD 20832
#   -> Attempting to geocode: 16227 Batchellors Forest Rd Olney MD 20832
#   -> Geocoder returned None for: 16227 Batchellors Forest Rd Olney MD 20832
#
# Processing 875/924: Attn: Harvest Intercontinental Church 16227 Batchellors Forest Rd Olney MD 20832
#   -> Attempting to geocode: 16227 Batchellors Forest Rd Olney MD 20832
#   -> Geocoder returned None for: 16227 Batchellors Forest Rd Olney MD 20832
#
# Processing 876/924: Attn: Haymarket Regional Food Pantry 7669 Limestone Drive Gainesville VA 20155
#   -> Attempting to geocode: 7669 Limestone Drive Gainesville VA 20155
#   -> Geocoder returned None for: 7669 Limestone Drive Gainesville VA 20155
#
# Processing 877/924: Attn: Largo Community Church 505 Largo Rd SW Side Upper Marlboro MD 20774
#   -> Attempting to geocode: 505 Largo Rd SW Side Upper Marlboro MD 20774
#   -> Geocoder returned None for: 505 Largo Rd SW Side Upper Marlboro MD 20774
#
# Processing 878/924: Attn: River of Life Redeemed Christian Church of God 5617 54th Ave. Riverdale MD 20737
#   -> Attempting to geocode: 5617 54th Ave. Riverdale MD 20737
#
# Processing 879/924: Attn: First Baptist Church of Silver Spring Food Closet 828 Wayne Ave Silver Spring MD 20910
#   -> Attempting to geocode: 828 Wayne Ave Silver Spring MD 20910
#
# Processing 880/924: Attn: NHT Communities 2629 Douglass Rd SE Washington DC DC 20020
#   -> Attempting to geocode: 2629 Douglass Rd SE Washington DC DC 20020
#   -> Geocoder returned None for: 2629 Douglass Rd SE Washington DC DC 20020
#
# Processing 881/924: Attn: ISKCON of Washington 10310 Oaklyn Dr Potomac MD 20854
#   -> Attempting to geocode: 10310 Oaklyn Dr Potomac MD 20854
#   -> Geocoder returned None for: 10310 Oaklyn Dr Potomac MD 20854
#
# Processing 882/924: Attn: ISKCON of Washington 10310 Oaklyn Dr Potomac MD 20854
#   -> Attempting to geocode: 10310 Oaklyn Dr Potomac MD 20854
#   -> Geocoder returned None for: 10310 Oaklyn Dr Potomac MD 20854
#
# Processing 883/924: Attn: ISKCON of Washington 10310 Oaklyn Dr Potomac MD 20854
#   -> Attempting to geocode: 10310 Oaklyn Dr Potomac MD 20854
#   -> Geocoder returned None for: 10310 Oaklyn Dr Potomac MD 20854
#
# Processing 884/924: Attn: ISKCON of Washington 10310 Oaklyn Dr Potomac MD 20854
#   -> Attempting to geocode: 10310 Oaklyn Dr Potomac MD 20854
#   -> Geocoder returned None for: 10310 Oaklyn Dr Potomac MD 20854
#
# Processing 885/924: Attn: ISKCON of Washington 10310 Oaklyn Dr Potomac MD 20854
#   -> Attempting to geocode: 10310 Oaklyn Dr Potomac MD 20854
#   -> Geocoder returned None for: 10310 Oaklyn Dr Potomac MD 20854
#
# Processing 886/924: Attn: Greater New Hope Baptist Church 816 8th STREET NW Washington DC 20001
#   -> Attempting to geocode: 816 8th STREET NW Washington DC 20001
#
# Processing 887/924: Attn: Largo Community Church 1701 Enterprise Road Mitchellville MD 20721
#   -> Attempting to geocode: 1701 Enterprise Road Mitchellville MD 20721
#   -> Geocoder returned None for: 1701 Enterprise Road Mitchellville MD 20721
#
# Processing 888/924: Esther Jordan 4142 Bunker Hill Rd Brentwood MD 20722
#   -> Attempting to geocode: 4142 Bunker Hill Rd Brentwood MD 20722
#
# Processing 889/924: Attn: Metropolis Club 938 Rhode Island Ave NE Washington DC 20018
#   -> Attempting to geocode: 938 Rhode Island Ave NE Washington DC 20018
#
# Processing 890/924: Attn: Ebenezer AME Church 7703 Allentown Road Fort Washington MD 20744
#   -> Attempting to geocode: 7703 Allentown Road Fort Washington MD 20744
#   -> Geocoder returned None for: 7703 Allentown Road Fort Washington MD 20744
#
# Processing 891/924: Attn: Ebenezer AME Church 7703 Allentown Road Fort Washington MD 20744
#   -> Attempting to geocode: 7703 Allentown Road Fort Washington MD 20744
#   -> Geocoder returned None for: 7703 Allentown Road Fort Washington MD 20744
#
# Processing 892/924: Attn: Ebenezer AME Church 7703 Allentown Road Fort Washington MD 20744
#   -> Attempting to geocode: 7703 Allentown Road Fort Washington MD 20744
#   -> Geocoder returned None for: 7703 Allentown Road Fort Washington MD 20744
#
# Processing 893/924: Attn: Ebenezer AME Church 7703 Allentown Road Fort Washington MD 20744
#   -> Attempting to geocode: 7703 Allentown Road Fort Washington MD 20744
#   -> Geocoder returned None for: 7703 Allentown Road Fort Washington MD 20744
#
# Processing 894/924: Attn: Grace of God Ministry 3950 48th Street Bladensburg MD 20710
#   -> Attempting to geocode: 3950 48th Street Bladensburg MD 20710
#
# Processing 895/924: Attn: Holy Family Catholic Church Food Pantry 14160 Ferndale Road Dale City VA 22193
#   -> Attempting to geocode: 14160 Ferndale Road Dale City VA 22193
#   -> Geocoder returned None for: 14160 Ferndale Road Dale City VA 22193
#
# Processing 896/924: Attn: Holy Family Catholic Church Food Pantry 14160 Ferndale Road Dale City VA 22193
#   -> Attempting to geocode: 14160 Ferndale Road Dale City VA 22193
#   -> Geocoder returned None for: 14160 Ferndale Road Dale City VA 22193
#
# Processing 897/924: Attn: Sacred Heart Catholic Church 12975 Purcell Road Manassas VA 20112
#   -> Attempting to geocode: 12975 Purcell Road Manassas VA 20112
#   -> Geocoder returned None for: 12975 Purcell Road Manassas VA 20112
#
# Processing 898/924: Attn: Manassas Baptist Church 8730 Sudley Road Manassas VA 20110
#   -> Attempting to geocode: 8730 Sudley Road Manassas VA 20110
#
# Processing 899/924: Attn: INOVA Cares for Women and Children Falls Church 6400 Arlington Blvd Falls Church VA 22042
#   -> Attempting to geocode: 6400 Arlington Blvd Falls Church VA 22042
#
# Processing 900/924: Attn: INOVA Cares for Women and Children Falls Church 6400 Arlington Blvd Falls Church VA 22042
#   -> Attempting to geocode: 6400 Arlington Blvd Falls Church VA 22042
#
# Processing 901/924: Attn: INOVA Cares for Women and Children Falls Church 6400 Arlington Blvd Falls Church VA 22042
#   -> Attempting to geocode: 6400 Arlington Blvd Falls Church VA 22042
#
# Processing 902/924: Attn: INOVA Cares for Women and Children Falls Church 6400 Arlington Blvd Falls Church VA 22042
#   -> Attempting to geocode: 6400 Arlington Blvd Falls Church VA 22042
#
# Processing 903/924: Attn: INOVA Cares for Women and Children Falls Church 6400 Arlington Blvd Falls Church VA 22042
#   -> Attempting to geocode: 6400 Arlington Blvd Falls Church VA 22042
#
# Processing 904/924: Attn: INOVA Cares for Women and Children Falls Church 6400 Arlington Blvd Falls Church VA 22042
#   -> Attempting to geocode: 6400 Arlington Blvd Falls Church VA 22042
#
# Processing 905/924: Attn: Shabach Emergency Empowerment Center 403 Brightseat Rd Landover MD 20785
#   -> Attempting to geocode: 403 Brightseat Rd Landover MD 20785
#
# Processing 906/924: Attn: Love Church 14370 Lee Highway Suite 105 Gainesville VA 20155
#   -> Attempting to geocode: 14370 Lee Highway Suite 105 Gainesville VA 20155
#   -> Geocoder returned None for: 14370 Lee Highway Suite 105 Gainesville VA 20155
#
# Processing 907/924: Attn: Love Church 14370 Lee Highway Suite 105 Gainesville VA 20155
#   -> Attempting to geocode: 14370 Lee Highway Suite 105 Gainesville VA 20155
#   -> Geocoder returned None for: 14370 Lee Highway Suite 105 Gainesville VA 20155
#
# Processing 908/924: Attn: Centro de Apoyo Familiar (CAF) 13923 Minnieville Road  Woodbridge VA 22193
#   -> Attempting to geocode: 13923 Minnieville Road Woodbridge VA 22193
#
# Processing 909/924: Attn: Friends Of Douglas Community Center 3261 Stanton Road SE Washington DC 20020
#   -> Attempting to geocode: 3261 Stanton Road SE Washington DC 20020
#
# Processing 910/924: Attn: Tender Love & Care 822 Cox Ave Hyattsville MD 20783
#   -> Attempting to geocode: 822 Cox Ave Hyattsville MD 20783
#
# Processing 911/924: Attn: Shiloh Church Of God 7 Day 5701 Eastern Ave Hyattsville MD 20781
#   -> Attempting to geocode: 7 Day 5701 Eastern Ave Hyattsville MD 20781
#   -> Geocoder returned None for: 7 Day 5701 Eastern Ave Hyattsville MD 20781
#
# Processing 912/924: Attn: Antioch Baptist Church of Clinton 9107 Pine View Lane Clinton MD 20735
#   -> Attempting to geocode: 9107 Pine View Lane Clinton MD 20735
#   -> Geocoder returned None for: 9107 Pine View Lane Clinton MD 20735
#
# Processing 913/924: Attn: Friends Of Douglas Community Center 3261 Stanton Road SE Washington DC 20020
#   -> Attempting to geocode: 3261 Stanton Road SE Washington DC 20020
#
# Processing 914/924: Attn: SevaTruck Foundation 2815 Old Lee Hwy Fairfax Fairfax VA 22031
#   -> Attempting to geocode: 2815 Old Lee Hwy Fairfax Fairfax VA 22031
#
# Processing 915/924: Attn: SevaTruck Foundation 2815 Old Lee Hwy Fairfax Fairfax VA 22031
#   -> Attempting to geocode: 2815 Old Lee Hwy Fairfax Fairfax VA 22031
#
# Processing 916/924: Attn: Spanish Catholic Center 1618 Monroe St. NW Washington DC 20010
#   -> Attempting to geocode: 1618 Monroe St. NW Washington DC 20010
#
# Processing 917/924: Attn: Clothing of Power Eternal Church 25 Quire Ave Capitol Heights MD 20743
#   -> Attempting to geocode: 25 Quire Ave Capitol Heights MD 20743
#
# Processing 918/924: Attn: Calvary Episcopal Church 509 I Street NE Washington DC 20002
#   -> Attempting to geocode: 509 I Street NE Washington DC 20002
#
# Processing 919/924: Attn: Gethsemane United Methodist Church 910 Addison Road Capitol Heights MD 20743
#   -> Attempting to geocode: 910 Addison Road Capitol Heights MD 20743
#
# Processing 920/924: Attn: LindaBen Foundation 10739 Tucker St.  Beltsville  MD 20705
#   -> Attempting to geocode: 10739 Tucker St. Beltsville MD 20705
#
# Processing 921/924: Attn: The Upcounty Hub Inc 12900 Middlebrook Road Suite 1100  Germantown  MD 20874
#   -> Attempting to geocode: 12900 Middlebrook Road Suite 1100 Germantown MD 20874
#   -> Geocoder returned None for: 12900 Middlebrook Road Suite 1100 Germantown MD 20874
#
# Processing 922/924: Attn: The Upcounty Hub Inc 12900 Middlebrook Road Suite 1100  Germantown  MD 20874
#   -> Attempting to geocode: 12900 Middlebrook Road Suite 1100 Germantown MD 20874
#   -> Geocoder returned None for: 12900 Middlebrook Road Suite 1100 Germantown MD 20874
#
# Processing 923/924: Attn: The Upcounty Hub Inc 12900 Middlebrook Road Suite 1100  Germantown  MD 20874
#   -> Attempting to geocode: 12900 Middlebrook Road Suite 1100 Germantown MD 20874
#   -> Geocoder returned None for: 12900 Middlebrook Road Suite 1100 Germantown MD 20874
#
# Processing 924/924: Attn: Dupont Park SDA Church 3942 Alabama Ave SE Washington DC 20019
#   -> Attempting to geocode: 3942 Alabama Ave SE Washington DC 20019
#
# Geocoding complete. Results saved to geocoded_addresses.csv
# Total addresses: 924, Successful: 638, Failed: 286

# %%
# --- Step 2: Get User Input and Find Closest ---
if os.path.exists(GECODED_FILE): # Only proceed if preprocessing was successful or file exists
    user_input = input("\nEnter an address to find nearby locations: ")
    if user_input:
        closest_addresses = find_closest(user_input, GECODED_FILE, num_closest=10)

        if closest_addresses:
            print("\nTop 10 Closest Addresses:")
            for i, (dist, addr) in enumerate(closest_addresses):
                print(f"{i+1}. {addr} ({dist:.2f} km away)")
        else:
            print("Could not find closest addresses.")
    else:
        print("No address entered.")
else:
    print(f"\nCannot proceed: Geocoded file '{GECODED_FILE}' not found.")
    print("Please ensure the preprocessing step ran successfully and created the file.")
# Out:
# Geocoding user address: 5033 Wilson Lane Bethesda MD 20814
#   -> Cleaned user address: 5033 Wilson Lane Bethesda MD 20814
# User coordinates: (38.9896048, -77.1229785)
#
# Top 10 Closest Addresses:
# 1. 5033 Wilson Lane Bethesda MD 20814 (0.00 km away)
# 2. 1908 North Capitol Street NW Washington DC 20002 (12.80 km away)
